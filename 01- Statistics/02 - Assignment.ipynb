# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Reading dataset
salesunit = pd.read_excel('./data/df_salesunit.xlsx')
salesunit
# Out:
#       Continent   Sales  (unit)
# 0  North America           1500
# 1  South America            500
# 2         Europe           1500
# 3           Asia           2000
# 4        Oceania           1000
# 5         Africa            500
# 6     Antarctica              1

# %%
salesunit.keys()
# Out:
# Index(['Continent ', 'Sales  (unit)'], dtype='object')

# %%
# set index 
salesunit = salesunit.set_index('Continent ')
salesunit
# Out:
#                Sales  (unit)
# Continent
# North America           1500
# South America            500
# Europe                  1500
# Asia                    2000
# Oceania                 1000
# Africa                   500
# Antarctica                 1

# %%
plt.style.use('seaborn')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# visualize
#plt.figure(figsize=())
salesunit['Sales  (unit)'].plot.pie()

# bar plot
salesunit.plot.bar()


# bar horizontal plt
salesunit.plot.barh()

# %%
# sales 
sales = pd.read_excel('./data/df_sales.xlsx')
sales.keys()
# Out:
# Index(['Genre', '2016 (sales)', '2017 (sales)'], dtype='object')

# %%
sales = sales.set_index('Genre')
sales
# Out:
#           2016 (sales)  2017 (sales)
# Genre
# Sports           14000         27500
# Strategy         15000         12500
# Action            7000          6000
# Shooter           5000          3500

# %% [markdown]
# ### Bar chart

# %%
sales.plot.bar()
sales.plot.barh()

# %% [markdown]
# #### Segmented bar plot

# %%
sales.plot.bar(stacked = True)
sales.plot.barh(stacked = True)

# %% [markdown]
# ### Scores

# %%
score = pd.read_excel('./data/df_scores.xlsx')
score = score.set_index('Scores ')

# %%
score.keys()
# Out:
# Index(['Frequency'], dtype='object')

# %%
# visualizing
score['Frequency'].plot.pie()
score.plot.bar()
score.plot.barh()
